# %% [markdown]
# # Predicting Car Prices

# %%
# importing packages and read data

import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
# %matplotlib inline

cars = pd.read_csv('imports-85.data')

header = ['symboling','normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']
cars.columns = header

cars.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
# 5          1               158         audi       gas        std         four
# 6          1                 ?         audi       gas        std         four
# 7          1               158         audi       gas      turbo         four
# 8          0                 ?         audi       gas      turbo          two
# 9          2               192          bmw       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1    hatchback          rwd           front        94.5  ...            152
# 2        sedan          fwd           front        99.8  ...            109
# 3        sedan          4wd           front        99.4  ...            136
# 4        sedan          fwd           front        99.8  ...            136
# 5        sedan          fwd           front       105.8  ...            136
# 6        wagon          fwd           front       105.8  ...            136
# 7        sedan          fwd           front       105.8  ...            131
# 8    hatchback          4wd           front        99.5  ...            131
# 9        sedan          rwd           front       101.2  ...            108
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  2.68    3.47               9.0        154      5000       19
# 2         mpfi  3.19    3.40              10.0        102      5500       24
# 3         mpfi  3.19    3.40               8.0        115      5500       18
# 4         mpfi  3.19    3.40               8.5        110      5500       19
# 5         mpfi  3.19    3.40               8.5        110      5500       19
# 6         mpfi  3.19    3.40               8.5        110      5500       19
# 7         mpfi  3.13    3.40               8.3        140      5500       17
# 8         mpfi  3.13    3.40               7.0        160      5500       16
# 9         mpfi  3.50    2.80               8.8        101      5800       23
#
#   highway-mpg  price
# 0          27  16500
# 1          26  16500
# 2          30  13950
# 3          22  17450
# 4          25  15250
# 5          25  17710
# 6          25  18920
# 7          20  23875
# 8          22      ?
# 9          29  16430
#
# [10 rows x 26 columns]

# %% [markdown]
# ## Checking and Cleaning Data

# %%
# Replacing '?' in the data with nan then see which column has nan

print(cars.info())
cars = cars.replace('?',np.nan)
print(cars.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
# symboling            204 non-null int64
# normalized-losses    204 non-null object
# make                 204 non-null object
# fuel-type            204 non-null object
# aspiration           204 non-null object
# num-of-doors         204 non-null object
# body-style           204 non-null object
# drive-wheels         204 non-null object
# engine-location      204 non-null object
# wheel-base           204 non-null float64
# length               204 non-null float64
# width                204 non-null float64
# height               204 non-null float64
# curb-weight          204 non-null int64
# engine-type          204 non-null object
# num-of-cylinders     204 non-null object
# engine-size          204 non-null int64
# fuel-system          204 non-null object
# bore                 204 non-null object
# stroke               204 non-null object
# compression-ratio    204 non-null float64
# horsepower           204 non-null object
# peak-rpm             204 non-null object
# city-mpg             204 non-null int64
# highway-mpg          204 non-null int64
# price                204 non-null object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 28.7+ KB
# None
# symboling             0
# normalized-losses    40
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# clear out na
cars = cars.dropna(subset=['price'])
print(cars.isnull().sum())

# Replacing string to number so we can change to float/int
num = {'eight':8, 'five':5, 'four':4, 'six':6, 'three':3, 'twelve':12, 'two':2}
cars=cars.replace({'num-of-doors':num,'num-of-cylinders':num})
cars = cars.astype({'normalized-losses':float,'bore':float,'stroke': float,'horsepower':float,'peak-rpm':float,'price':int})

# Averaging out missing values in columns
cars = cars.fillna(cars.mean())
#cars['normalized-losses'] = cars['normalized-losses'].fillna(cars['normalized-losses'].mean())

print(cars.info())
print(cars.head(10))
print(cars.isnull().sum())
# Out:
# symboling             0
# normalized-losses    36
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 203
# Data columns (total 26 columns):
# symboling            200 non-null int64
# normalized-losses    200 non-null float64
# make                 200 non-null object
# fuel-type            200 non-null object
# aspiration           200 non-null object
# num-of-doors         200 non-null float64
# body-style           200 non-null object
# drive-wheels         200 non-null object
# engine-location      200 non-null object
# wheel-base           200 non-null float64
# length               200 non-null float64
# width                200 non-null float64
# height               200 non-null float64
# curb-weight          200 non-null int64
# engine-type          200 non-null object
# num-of-cylinders     200 non-null int64
# engine-size          200 non-null int64
# fuel-system          200 non-null object
# bore                 200 non-null float64
# stroke               200 non-null float64
# compression-ratio    200 non-null float64
# horsepower           200 non-null float64
# peak-rpm             200 non-null float64
# city-mpg             200 non-null int64
# highway-mpg          200 non-null int64
# price                200 non-null int32
# dtypes: float64(11), int32(1), int64(6), object(8)
# memory usage: 35.2+ KB
# None
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3              122.0  alfa-romero       gas        std
# 1           1              122.0  alfa-romero       gas        std
# 2           2              164.0         audi       gas        std
# 3           2              164.0         audi       gas        std
# 4           2              122.0         audi       gas        std
# 5           1              158.0         audi       gas        std
# 6           1              122.0         audi       gas        std
# 7           1              158.0         audi       gas      turbo
# 9           2              192.0          bmw       gas        std
# 10          0              192.0          bmw       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...    \
# 0            2.0  convertible          rwd           front        88.6  ...
# 1            2.0    hatchback          rwd           front        94.5  ...
# 2            4.0        sedan          fwd           front        99.8  ...
# 3            4.0        sedan          4wd           front        99.4  ...
# 4            2.0        sedan          fwd           front        99.8  ...
# 5            4.0        sedan          fwd           front       105.8  ...
# 6            4.0        wagon          fwd           front       105.8  ...
# 7            4.0        sedan          fwd           front       105.8  ...
# 9            2.0        sedan          rwd           front       101.2  ...
# 10           4.0        sedan          rwd           front       101.2  ...
#
#     engine-size  fuel-system  bore  stroke compression-ratio  horsepower  \
# 0           130         mpfi  3.47    2.68               9.0       111.0
# 1           152         mpfi  2.68    3.47               9.0       154.0
# 2           109         mpfi  3.19    3.40              10.0       102.0
# 3           136         mpfi  3.19    3.40               8.0       115.0
# 4           136         mpfi  3.19    3.40               8.5       110.0
# 5           136         mpfi  3.19    3.40               8.5       110.0
# 6           136         mpfi  3.19    3.40               8.5       110.0
# 7           131         mpfi  3.13    3.40               8.3       140.0
# 9           108         mpfi  3.50    2.80               8.8       101.0
# 10          108         mpfi  3.50    2.80               8.8       101.0
#
#     peak-rpm city-mpg  highway-mpg  price
# 0     5000.0       21           27  16500
# 1     5000.0       19           26  16500
# 2     5500.0       24           30  13950
# 3     5500.0       18           22  17450
# 4     5500.0       19           25  15250
# 5     5500.0       19           25  17710
# 6     5500.0       19           25  18920
# 7     5500.0       17           20  23875
# 9     5800.0       23           29  16430
# 10    5800.0       23           29  16925
#
# [10 rows x 26 columns]
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# excluding non numeric columns and convert to float
numeric_cars = cars.select_dtypes(exclude=['object']) #!= object
columns_numeric = numeric_cars.columns.tolist()
price_column = numeric_cars['price']
numeric_cars = numeric_cars.astype('float')
print(price_column.shape)
print(numeric_cars.info())
print(numeric_cars.index)

# Normalize the data using Normalization formula = (x-min(x))/(max(x)-min(x))
normalized_cars = (numeric_cars - numeric_cars.min())/(numeric_cars.max() - numeric_cars.min())
print(normalized_cars.index)

#re-add non-normalized price column
normalized_cars['price'] = price_column
print(normalized_cars.info())
print(normalized_cars.isnull().sum())
print(normalized_cars.head(10))
# Out:
# (200,)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 203
# Data columns (total 18 columns):
# symboling            200 non-null float64
# normalized-losses    200 non-null float64
# num-of-doors         200 non-null float64
# wheel-base           200 non-null float64
# length               200 non-null float64
# width                200 non-null float64
# height               200 non-null float64
# curb-weight          200 non-null float64
# num-of-cylinders     200 non-null float64
# engine-size          200 non-null float64
# bore                 200 non-null float64
# stroke               200 non-null float64
# compression-ratio    200 non-null float64
# horsepower           200 non-null float64
# peak-rpm             200 non-null float64
# city-mpg             200 non-null float64
# highway-mpg          200 non-null float64
# price                200 non-null float64
# dtypes: float64(18)
# memory usage: 29.7 KB
# None
# Int64Index([  0,   1,   2,   3,   4,   5,   6,   7,   9,  10,
#             ...
#             194, 195, 196, 197, 198, 199, 200, 201, 202, 203],
#            dtype='int64', length=200)
# Int64Index([  0,   1,   2,   3,   4,   5,   6,   7,   9,  10,
#             ...
#             194, 195, 196, 197, 198, 199, 200, 201, 202, 203],
#            dtype='int64', length=200)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 203
# Data columns (total 18 columns):
# symboling            200 non-null float64
# normalized-losses    200 non-null float64
# num-of-doors         200 non-null float64
# wheel-base           200 non-null float64
# length               200 non-null float64
# width                200 non-null float64
# height               200 non-null float64
# curb-weight          200 non-null float64
# num-of-cylinders     200 non-null float64
# engine-size          200 non-null float64
# bore                 200 non-null float64
# stroke               200 non-null float64
# compression-ratio    200 non-null float64
# horsepower           200 non-null float64
# peak-rpm             200 non-null float64
# city-mpg             200 non-null float64
# highway-mpg          200 non-null float64
# price                200 non-null int32
# dtypes: float64(17), int32(1)
# memory usage: 28.9 KB
# None
# symboling            0
# normalized-losses    0
# num-of-doors         0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# num-of-cylinders     0
# engine-size          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64
#     symboling  normalized-losses  num-of-doors  wheel-base    length  \
# 0         1.0           0.298429           0.0    0.058309  0.413433
# 1         0.6           0.298429           0.0    0.230321  0.449254
# 2         0.8           0.518325           1.0    0.384840  0.529851
# 3         0.8           0.518325           1.0    0.373178  0.529851
# 4         0.8           0.298429           0.0    0.384840  0.540299
# 5         0.6           0.486911           1.0    0.559767  0.770149
# 6         0.6           0.298429           1.0    0.559767  0.770149
# 7         0.6           0.486911           1.0    0.559767  0.770149
# 9         0.8           0.664921           0.0    0.425656  0.532836
# 10        0.4           0.664921           1.0    0.425656  0.532836
#
#        width    height  curb-weight  num-of-cylinders  engine-size      bore  \
# 0   0.324786  0.083333     0.411171               0.2     0.260377  0.664286
# 1   0.444444  0.383333     0.517843               0.4     0.343396  0.100000
# 2   0.504274  0.541667     0.329325               0.2     0.181132  0.464286
# 3   0.521368  0.541667     0.518231               0.3     0.283019  0.464286
# 4   0.512821  0.441667     0.395268               0.3     0.283019  0.464286
# 5   0.948718  0.658333     0.525989               0.3     0.283019  0.464286
# 6   0.948718  0.658333     0.568658               0.3     0.283019  0.464286
# 7   0.948718  0.675000     0.619860               0.3     0.264151  0.421429
# 9   0.384615  0.541667     0.351823               0.2     0.177358  0.685714
# 10  0.384615  0.541667     0.351823               0.2     0.177358  0.685714
#
#       stroke  compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg  \
# 0   0.290476            0.12500    0.294393  0.346939  0.222222     0.289474
# 1   0.666667            0.12500    0.495327  0.346939  0.166667     0.263158
# 2   0.633333            0.18750    0.252336  0.551020  0.305556     0.368421
# 3   0.633333            0.06250    0.313084  0.551020  0.138889     0.157895
# 4   0.633333            0.09375    0.289720  0.551020  0.166667     0.236842
# 5   0.633333            0.09375    0.289720  0.551020  0.166667     0.236842
# 6   0.633333            0.09375    0.289720  0.551020  0.166667     0.236842
# 7   0.633333            0.08125    0.429907  0.551020  0.111111     0.105263
# 9   0.347619            0.11250    0.247664  0.673469  0.277778     0.342105
# 10  0.347619            0.11250    0.247664  0.673469  0.277778     0.342105
#
#     price
# 0   16500
# 1   16500
# 2   13950
# 3   17450
# 4   15250
# 5   17710
# 6   18920
# 7   23875
# 9   16430
# 10  16925

# %% [markdown]
# ## Univariate Model

# %%
# Define our k nearest neighbor (knn) function
def knn_train_test(train_col,target_col,df):
    # Randomize the dataset
    np.random.seed(1)
    shuffled_index = np.random.permutation(df.index)
    rand_df = df.reindex(shuffled_index)

    # splitting the dataset into train and test datasets
    train_df = rand_df[:145]
    test_df = rand_df[145:]
    
    # train the knn and make predictions on test df
    knn = KNeighborsRegressor()
    knn.fit(train_df[[train_col]],train_df[target_col])
    predictions = knn.predict(test_df[[train_col]])
    
    # find root mean squared error
    rmse = mean_squared_error(test_df[target_col],predictions) ** (1/2)
    return rmse

# %%
train_cols = normalized_cars.drop(['price'], axis = 1).columns
rmses = {}
lowest_rmse ={}
for train_col in train_cols:
    rmse = knn_train_test(train_col,'price',normalized_cars)
    rmses[train_col] = rmse

print(rmses, '\n')

# Convert rmses to series for better display
rmses_series = pd.Series(rmses)
print(rmses_series.sort_values(),'\n')

# Get lowest rmse
min_key = min(rmses, key = rmses.get)
lowest_rmse[min_key] = rmses[min_key]

print(lowest_rmse)

# Visualize the results
x = [x for x in range(len(train_cols))]
plt.scatter(list(rmses.keys()),list(rmses.values()))
plt.xticks(rotation=90)
plt.show()
# Out:
# {'symboling': 7393.3772992763288, 'normalized-losses': 6686.9453688375661, 'num-of-doors': 7484.108087893489, 'wheel-base': 5588.1113681880688, 'length': 4755.6965896796773, 'width': 3568.0706828506331, 'height': 7179.4544485572915, 'curb-weight': 3081.781605382303, 'num-of-cylinders': 4959.9460898829793, 'engine-size': 2690.6136573449021, 'bore': 7294.439682936586, 'stroke': 6700.2614794023984, 'compression-ratio': 6966.9771485983001, 'horsepower': 5256.6014861315098, 'peak-rpm': 7151.2272660139824, 'city-mpg': 3246.8056392258977, 'highway-mpg': 3572.7217977843784}
#
# engine-size          2690.613657
# curb-weight          3081.781605
# city-mpg             3246.805639
# width                3568.070683
# highway-mpg          3572.721798
# length               4755.696590
# num-of-cylinders     4959.946090
# horsepower           5256.601486
# wheel-base           5588.111368
# normalized-losses    6686.945369
# stroke               6700.261479
# compression-ratio    6966.977149
# peak-rpm             7151.227266
# height               7179.454449
# bore                 7294.439683
# symboling            7393.377299
# num-of-doors         7484.108088
# dtype: float64
#
# {'engine-size': 2690.6136573449021}

# %% [markdown]
# Engine size gives the lowest RMSE of 2690 for our univariate model at default k = 5

# %%
# Change our function so it accepts k value
def knn_train_test_k(train_col,target_col,df,k):
    # Randomize the dataset
    np.random.seed(1)
    shuffled_index = np.random.permutation(df.index)
    rand_df = df.reindex(shuffled_index)

    # splitting the dataset into train and test datasets
    train_df = rand_df[:145]
    test_df = rand_df[145:]
    
    # train the knn and make predictions on test df
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(train_df[[train_col]],train_df[target_col])
    predictions = knn.predict(test_df[[train_col]])
    
    # find root mean squared error
    rmse = mean_squared_error(test_df[target_col],predictions) ** (1/2)
    return rmse

# %%
# Train our model using different k values and iterate for each column
k_values = [1,3,5,7,9]

total_rmses = {}

for train_col in train_cols:
    rmses_k = {}
    for k in k_values:
        rmse_k = knn_train_test_k (train_col,'price',normalized_cars,k)
        rmses_k[k] = rmse_k
    total_rmses[train_col] = rmses_k       

# Visualize our results
for kee,val in total_rmses.items():
    x = list(val.keys())
    y = list(val.values())
    print(kee,val)
    plt.plot(x,y)
    plt.xlabel('k')
    plt.ylabel('RMSE')

# Turn our results into a dataframe for easy data manipulation
total_rmses_df = pd.DataFrame(data=total_rmses)
print(total_rmses_df)

# Minimum rmse for each column
min_rmse_each_col = pd.DataFrame({'min': total_rmses_df.min(), 'k value': total_rmses_df.idxmin()})
print('\nMin RMSE for each column:\n',min_rmse_each_col.sort_values('min'))

# Mean rmse for each colum
print('\nMean RMSE for each column:\n',total_rmses_df.mean().sort_values())
# Out:
# symboling {1: 8485.6822268186224, 3: 7192.9106738243418, 5: 7393.3772992763288, 7: 7343.6599922656887, 9: 7626.0711454147249}
# normalized-losses {1: 6732.0779029144551, 3: 7221.4591361126913, 5: 6686.9453688375661, 7: 6839.5707081647424, 9: 6839.7213417650755}
# num-of-doors {1: 8891.3435522218097, 3: 8063.8431464723499, 5: 7484.108087893489, 7: 7595.832613187943, 9: 8626.8948171449883}
# wheel-base {1: 4723.8893817392773, 3: 5293.8492170946211, 5: 5588.1113681880688, 7: 5400.0837046697425, 9: 5615.4179392586357}
# length {1: 5221.2823625131505, 3: 5227.0153033847309, 5: 4755.6965896796773, 7: 4824.4501707544632, 9: 4908.2217635905172}
# width {1: 5306.9644499211854, 3: 3627.5628090128685, 5: 3568.0706828506331, 7: 3444.2723798672109, 9: 3115.6402628652399}
# height {1: 6609.6499535974599, 3: 7533.0318714152254, 5: 7179.4544485572915, 7: 6965.718977337734, 9: 6916.7377431421673}
# curb-weight {1: 3421.392260469413, 3: 3442.2734004777085, 5: 3081.781605382303, 7: 2591.5950837839491, 9: 2756.0042325333725}
# num-of-cylinders {1: 6254.8679805848387, 3: 5121.5881866404825, 5: 4959.9460898829793, 7: 4973.7091799086902, 9: 4961.5732303689983}
# engine-size {1: 3569.5488688730297, 3: 2789.6269505495397, 5: 2690.6136573449021, 7: 2761.8076100542589, 9: 2829.8919919266914}
# bore {1: 8872.211477928764, 3: 8366.5933366338577, 5: 7294.439682936586, 7: 7137.9206060643919, 9: 7453.8385695476009}
# stroke {1: 8848.2392722044879, 3: 6909.1190308040132, 5: 6700.2614794023984, 7: 6843.4100174394316, 9: 6969.9703283605668}
# compression-ratio {1: 7885.841946171633, 3: 7326.6760636330955, 5: 6966.9771485983001, 7: 6400.840875534609, 9: 6654.3207033734525}
# horsepower {1: 4889.3589429215845, 3: 4589.3579690057695, 5: 5256.6014861315098, 7: 4741.5424850635191, 9: 4519.863204851712}
# peak-rpm {1: 10119.28815857932, 3: 6237.3123887090533, 5: 7151.2272660139824, 7: 6588.7095407968172, 9: 6997.8112358422732}
# city-mpg {1: 4620.6128656862666, 3: 4142.6480298222168, 5: 3246.8056392258977, 7: 3248.7554028477539, 9: 3327.5423962217519}
# highway-mpg {1: 3569.4825471691906, 3: 3523.7807857843009, 5: 3572.7217977843784, 7: 3735.9897152071476, 9: 3563.3641110758322}
#           bore     city-mpg  compression-ratio  curb-weight  engine-size  \
# 1  8872.211478  4620.612866        7885.841946  3421.392260  3569.548869
# 3  8366.593337  4142.648030        7326.676064  3442.273400  2789.626951
# 5  7294.439683  3246.805639        6966.977149  3081.781605  2690.613657
# 7  7137.920606  3248.755403        6400.840876  2591.595084  2761.807610
# 9  7453.838570  3327.542396        6654.320703  2756.004233  2829.891992
#
#         height  highway-mpg   horsepower       length  normalized-losses  \
# 1  6609.649954  3569.482547  4889.358943  5221.282363        6732.077903
# 3  7533.031871  3523.780786  4589.357969  5227.015303        7221.459136
# 5  7179.454449  3572.721798  5256.601486  4755.696590        6686.945369
# 7  6965.718977  3735.989715  4741.542485  4824.450171        6839.570708
# 9  6916.737743  3563.364111  4519.863205  4908.221764        6839.721342
#
#    num-of-cylinders  num-of-doors      peak-rpm       stroke    symboling  \
# 1       6254.867981   8891.343552  10119.288159  8848.239272  8485.682227
# 3       5121.588187   8063.843146   6237.312389  6909.119031  7192.910674
# 5       4959.946090   7484.108088   7151.227266  6700.261479  7393.377299
# 7       4973.709180   7595.832613   6588.709541  6843.410017  7343.659992
# 9       4961.573230   8626.894817   6997.811236  6969.970328  7626.071145
#
#     wheel-base        width
# 1  4723.889382  5306.964450
# 3  5293.849217  3627.562809
# 5  5588.111368  3568.070683
# 7  5400.083705  3444.272380
# 9  5615.417939  3115.640263
#
# Min RMSE for each column:
#                     k value          min
# curb-weight              7  2591.595084
# engine-size              5  2690.613657
# width                    9  3115.640263
# city-mpg                 5  3246.805639
# highway-mpg              3  3523.780786
# horsepower               9  4519.863205
# wheel-base               1  4723.889382
# length                   5  4755.696590
# num-of-cylinders         5  4959.946090
# peak-rpm                 3  6237.312389
# compression-ratio        7  6400.840876
# height                   1  6609.649954
# normalized-losses        5  6686.945369
# stroke                   5  6700.261479
# bore                     7  7137.920606
# symboling                3  7192.910674
# num-of-doors             5  7484.108088
#
# Mean RMSE for each column:
#  engine-size          2928.297816
# curb-weight          3058.609317
# highway-mpg          3593.067791
# city-mpg             3717.272867
# width                3812.502117
# horsepower           4799.344818
# length               4987.333238
# num-of-cylinders     5254.336933
# wheel-base           5324.270322
# normalized-losses    6863.954892
# height               7040.918599
# compression-ratio    7046.931347
# stroke               7254.200026
# peak-rpm             7418.869718
# symboling            7608.340268
# bore                 7825.000735
# num-of-doors         8132.404443
# dtype: float64

# %% [markdown]
# Looking at the results, curb weight gives the lowest RMSE of 2591 at k = 7 and on average, engine size will give lowest RMSE

# %% [markdown]
# ## Multivariate Model

# %%
# Modify our k nearest neighbor (knn) function to accept multiple columns
def multi_knn_train_test(train_col,target_col,df,k):
    
    # Randomize the dataset
    np.random.seed(1)
    shuffled_index = np.random.permutation(df.index)
    rand_df = df.reindex(shuffled_index)

    # splitting the dataset into train and test datasets
    train_df = rand_df[:145]
    test_df = rand_df[145:]
    
    # train the knn and make predictions on test df
    knn = KNeighborsRegressor(n_neighbors = k)
    knn.fit(train_df[train_col],train_df[target_col])
    predictions = knn.predict(test_df[train_col])
    
    # find root mean squared error
    rmse = mean_squared_error(test_df[target_col],predictions) ** (1/2)
    return rmse

# %%
# Train model on all columns 
rmse = multi_knn_train_test(list(train_cols),'price',normalized_cars,5)
print(rmse)
# Out:
# 4015.64401084

# %%
# Train model on best 2 columns 
best_two = ['curb-weight','engine-size']
rmse_best_two = multi_knn_train_test(best_two,'price',normalized_cars,5)
print('RMSE for best two features: ', rmse_best_two)

# Train model on best 3 columns 
best_three = ['curb-weight','engine-size','width']
rmse_best_three = multi_knn_train_test(best_three,'price',normalized_cars,5)
print('RMSE for best three features: ', rmse_best_three)

# Train model on best 4 columns 
best_four = ['curb-weight','engine-size','width','city-mpg']
rmse_best_four = multi_knn_train_test(best_four,'price',normalized_cars,5)
print('RMSE for best four features: ', rmse_best_four)

# Train model on best 5 columns 
best_five = ['curb-weight','engine-size','width','city-mpg','highway-mpg']
rmse_best_five = multi_knn_train_test(best_five,'price',normalized_cars,5)
print('RMSE for best five features: ', rmse_best_five)
# Out:
# RMSE for best two features:  2726.15154998
# RMSE for best three features:  2285.90037546
# RMSE for best four features:  2158.90144505
# RMSE for best five features:  2150.18938058

# %%
hyper_params = [k for k in range(1,26)]
rmses_top = {}
rmses_top_two = {}
rmses_top_three = {}
rmses_all = {}

for k in hyper_params:
    rmse_top = multi_knn_train_test(best_five,'price',normalized_cars,k)
    rmse_top_two = multi_knn_train_test(best_four,'price',normalized_cars,k)
    rmse_top_three = multi_knn_train_test(best_three,'price',normalized_cars,k)
    
    rmses_top[k] = rmse_top
    rmses_top_two[k] = rmse_top_two
    rmses_top_three[k] = rmse_top_three

rmses_all['top - best five'] = rmses_top
rmses_all['top two - best four'] = rmses_top_two
rmses_all['top three - best three'] = rmses_top_three

# Turn our results into a dataframe for easy data manipulation
rmses_all_df = pd.DataFrame(data=rmses_all)
print(rmses_all_df)

# Minimum rmse for top 1,2,3
min_rmse_top = pd.DataFrame({'min': rmses_all_df.min(), 'k value': rmses_all_df.idxmin()})
print('\nMin RMSE for top 1,2,3:\n',min_rmse_top.sort_values('min'))

# Visualize our results
for k,v in rmses_all.items():
    x = list(v.keys())
    y = list(v.values())
    plt.plot(x,y)
    plt.xlabel('k')
    plt.ylabel('RMSE')
# Out:
#     top - best five  top three - best three  top two - best four
# 1       2026.024648             2291.038780          2008.725937
# 2       2156.084194             2309.415350          1966.130538
# 3       2264.995536             2259.269447          2288.502359
# 4       2147.947129             2316.439277          2155.385817
# 5       2150.189381             2285.900375          2158.901445
# 6       2221.399184             2315.864661          2353.152759
# 7       2297.730700             2352.489987          2231.551730
# 8       2360.929008             2574.522048          2277.773359
# 9       2304.137108             2530.928367          2440.059921
# 10      2268.546850             2521.964229          2400.729852
# 11      2263.719727             2550.908933          2373.603592
# 12      2317.587088             2564.801986          2404.724598
# 13      2430.040911             2651.923900          2458.772350
# 14      2418.300551             2731.342446          2412.860208
# 15      2570.037073             2828.750762          2522.679596
# 16      2732.380682             2914.439696          2592.616189
# 17      2820.550734             2990.569263          2723.459931
# 18      2891.397901             3004.278213          2839.049071
# 19      2875.497730             3082.885775          2835.909349
# 20      2940.244166             3161.289109          2896.751029
# 21      3013.355798             3249.119596          2987.659943
# 22      3097.055767             3315.410607          3054.586277
# 23      3165.522695             3242.045349          3137.813252
# 24      3260.289237             3326.285124          3193.447574
# 25      3328.305707             3405.087540          3224.374566
#
# Min RMSE for top 1,2,3:
#                          k value          min
# top two - best four           2  1966.130538
# top - best five               1  2026.024648
# top three - best three        3  2259.269447

# %% [markdown]
# Based on the results, best four features ('curb-weight','engine-size','width','city-mpg') gives the lowest RMSE of 1966 at k = 2

# %% [markdown]
# ## KFold Cross Validation Method

# %%
from sklearn.model_selection import cross_val_score

def kfold_train_test_k(train_col,target_col,df,k):
    
    model = KNeighborsRegressor(n_neighbors=k)
    mses = cross_val_score(model, df[[train_col]], df[target_col], scoring="neg_mean_squared_error", cv=10)
    rmses = np.sqrt(np.abs(mses))
    avg_rmse = np.mean(rmses)
    
    return avg_rmse

kf_all_rmses = {}
for train_col in train_cols:
    kf_rmses = {}
    for k in k_values:
        kf_rmse = kfold_train_test_k(train_col,'price',normalized_cars,k)
        kf_rmses[k] = kf_rmse
    kf_all_rmses[train_col] = kf_rmses

# Turn our results into a dataframe for easy data manipulation
kf_all_rmses_df = pd.DataFrame(data=kf_all_rmses)
#print(total_rmses_df)

# Minimum rmse for each column
kf_min_rmse_each_col = pd.DataFrame({'min': kf_all_rmses_df.min(), 'k value': kf_all_rmses_df.idxmin()})
print('\nMin RMSE for each column:\n',kf_min_rmse_each_col.sort_values('min'))

# Mean rmse for each colum
print('\nMean RMSE for each column:\n',kf_all_rmses_df.mean().sort_values())
# Out:
# Min RMSE for each column:
#                     k value          min
# engine-size              9  3712.193148
# horsepower               7  4022.009225
# curb-weight              5  4122.684985
# highway-mpg              7  4187.594316
# width                    9  4348.786756
# city-mpg                 5  4621.649365
# length                   9  5919.107972
# num-of-cylinders         9  6264.305010
# compression-ratio        9  6723.817352
# wheel-base               9  6772.826078
# bore                     9  7232.463354
# num-of-doors             5  7624.761647
# height                   9  8022.834610
# symboling                5  8165.485021
# normalized-losses        7  8171.497271
# peak-rpm                 9  8326.751570
# stroke                   7  8547.503887
#
# Mean RMSE for each column:
#  engine-size          4088.662400
# curb-weight          4394.014194
# horsepower           4403.174497
# highway-mpg          4421.429727
# city-mpg             4907.025139
# width                4937.933027
# length               6694.744451
# wheel-base           7245.799573
# compression-ratio    7511.369894
# num-of-cylinders     7662.548468
# bore                 8032.803544
# num-of-doors         8113.342569
# symboling            8448.227849
# normalized-losses    8534.899277
# stroke               9156.222085
# peak-rpm             9291.722937
# height               9526.300374
# dtype: float64

# %% [markdown]
# ## GridsearchCV

# %%
from sklearn.model_selection import GridSearchCV

hyperparameters = {
    'n_neighbors': k_values,
    'algorithm': ['brute'],
    'p': [2]
}

knn = KNeighborsRegressor()
grid = GridSearchCV(knn, param_grid = hyperparameters, cv=10, scoring = 'neg_mean_squared_error')
grid.fit(normalized_cars[train_cols],normalized_cars['price'])
best_params = grid.best_params_
best_score = grid.best_score_
rmse_best_score = abs(best_score)**(1/2)

print(best_params)
print(rmse_best_score)
# Out:
# {'algorithm': 'brute', 'n_neighbors': 3, 'p': 2}
# 4854.70625539
